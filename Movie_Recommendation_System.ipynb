# %% [markdown]
# <a href="https://colab.research.google.com/github/surya676-beep/Movie-recommendation-/blob/main/Movie_Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load dataset
movies = pd.read_csv("/content/movies.csv.zip")
print(movies)
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
print(movies.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Show available genres
print("Available Genres:")
genres = set()

for genre_list in movies["genres"]:
    for genre in genre_list.split("|"):
        genres.add(genre)

print(sorted(genres))
# Out:
# Available Genres:
# ['(no genres listed)', 'Action', 'Adventure', 'Animation', 'Children', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Film-Noir', 'Horror', 'IMAX', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']

# %%
# Get user input
user_genre = input("\nEnter your favorite genre: ")
# Out:
# Enter your favorite genre: action

# %%
# Filter movies by genre
recommended_movies = movies[
    movies["genres"].str.lower().str.contains(user_genre.lower(), na=False)
]

# %%
# Select columns
recommended_movies = recommended_movies[["movieId", "title", "genres"]].head(10)

print("\nRecommended Movies:\n")

if recommended_movies.empty:
    print("Sorry, no movies found for this genre.")
else:
    print(recommended_movies.to_string(index=False))
# Out:
# Recommended Movies:
#
#  movieId                                     title                             genres
#        6                               Heat (1995)              Action|Crime|Thriller
#        9                       Sudden Death (1995)                             Action
#       10                          GoldenEye (1995)          Action|Adventure|Thriller
#       15                   Cutthroat Island (1995)           Action|Adventure|Romance
#       20                        Money Train (1995) Action|Comedy|Crime|Drama|Thriller
#       23                          Assassins (1995)              Action|Crime|Thriller
#       42                    Dead Presidents (1995)                 Action|Crime|Drama
#       44                      Mortal Kombat (1995)           Action|Adventure|Fantasy
#       51                     Guardian Angel (1994)              Action|Drama|Thriller
#       66 Lawnmower Man 2: Beyond Cyberspace (1996)             Action|Sci-Fi|Thriller
